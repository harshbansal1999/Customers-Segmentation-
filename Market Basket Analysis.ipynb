# %% [markdown]
# # Loading the Libraries

# %%
import numpy as np 
import pandas as pd 
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# # Data Processing And Cleaning

# %%
#Loading the dataset
df=pd.read_csv('transaction_data.csv')

# %%
#Filling NA values
df['ItemDescription'].fillna('Not Mentioned',inplace=True)
df=df[~(df['UserId']==-1)]

# %%
df.head()
# Out:
#    UserId  TransactionId               TransactionTime  ItemCode  \
# 0  278166        6355745  Sat Feb 02 12:50:00 IST 2019    465549
# 1  337701        6283376  Wed Dec 26 09:06:00 IST 2018    482370
# 2  267099        6385599  Fri Feb 15 09:45:00 IST 2019    490728
# 3  380478        6044973  Fri Jun 22 07:14:00 IST 2018    459186
# 5  285957        6307136  Fri Jan 11 09:50:00 IST 2019   1787247
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
# 3        UNION JACK FLAG LUGGAGE TAG                       3         1.73
# 5   CUT GLASS T-LIGHT HOLDER OCTAGON                      12         3.52
#
#           Country
# 0  United Kingdom
# 1  United Kingdom
# 2          France
# 3  United Kingdom
# 5  United Kingdom

# %%
# Transactions done in France 
basket_France = (df[df['Country'] =="France"] 
          .groupby(['TransactionId', 'ItemDescription'])['NumberOfItemsPurchased'] 
          .sum().unstack().reset_index().fillna(0) 
          .set_index('TransactionId')) 
  
# Transactions done in the United Kingdom 
basket_UK = (df[df['Country'] =="United Kingdom"] 
          .groupby(['TransactionId', 'ItemDescription'])['NumberOfItemsPurchased'] 
          .sum().unstack().reset_index().fillna(0) 
          .set_index('TransactionId')) 
  
# Transactions done in Germany 
basket_ger = (df[df['Country'] =="Germany"] 
          .groupby(['TransactionId', 'ItemDescription'])['NumberOfItemsPurchased'] 
          .sum().unstack().reset_index().fillna(0) 
          .set_index('TransactionId')) 

# Transactions done in Other Countries
basket_other = (df[~(df['Country']=='United Kingdom')&~(df['Country']=='France')&~(df['Country']=='Germany')] 
          .groupby(['TransactionId', 'ItemDescription'])['NumberOfItemsPurchased'] 
          .sum().unstack().reset_index().fillna(0) 
          .set_index('TransactionId'))

# %%
def hot_encode(x): 
    if(x<= 0): 
        return 0
    if(x>= 1): 
        return 1

# %%
# Encoding the datasets 
basket_encoded = basket_France.applymap(hot_encode) 
basket_France = basket_encoded 
  
basket_encoded = basket_UK.applymap(hot_encode) 
basket_UK = basket_encoded 
  
basket_encoded = basket_ger.applymap(hot_encode) 
basket_ger = basket_encoded 

basket_encoded = basket_other.applymap(hot_encode) 
basket_other = basket_encoded

# %%
#France
# Building the model 
frq_items = apriori(basket_France, min_support = 0.01, use_colnames = True) 
  
# Collecting the inferred rules in a dataframe 
rules1 = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules1 = rules1.sort_values(['confidence', 'lift'], ascending =[False, False]) 
rules1.head()
# Out:
#                                              antecedents  \
# 5372                      (SMALL MARSHMALLOWS PINK BOWL)
# 5373                (SMALL DOLLY MIX DESIGN ORANGE BOWL)
# 86707  (ALARM CLOCK BAKELIKE PINK, PLASTERS IN TIN CI...
# 86726  (PLASTERS IN TIN SPACEBOY, ALARM CLOCK BAKELIK...
# 89624  (ALARM CLOCK BAKELIKE RED , CHILDRENS CUTLERY ...
#
#                                              consequents  antecedent support  \
# 5372                (SMALL DOLLY MIX DESIGN ORANGE BOWL)            0.010917
# 5373                      (SMALL MARSHMALLOWS PINK BOWL)            0.010917
# 86707  (PLASTERS IN TIN SPACEBOY, ALARM CLOCK BAKELIK...            0.010917
# 86726  (ALARM CLOCK BAKELIKE PINK, PLASTERS IN TIN CI...            0.010917
# 89624      (ALARM CLOCK BAKELIKE PINK, CARD DOLLY GIRL )            0.010917
#
#        consequent support   support  confidence  lift  leverage  conviction
# 5372             0.010917  0.010917         1.0  91.6  0.010798         inf
# 5373             0.010917  0.010917         1.0  91.6  0.010798         inf
# 86707            0.010917  0.010917         1.0  91.6  0.010798         inf
# 86726            0.010917  0.010917         1.0  91.6  0.010798         inf
# 89624            0.010917  0.010917         1.0  91.6  0.010798         inf

# %%
#UK
# Building the model 
frq_items = apriori(basket_UK, min_support = 0.01, use_colnames = True) 
rules2 = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules2 = rules2.sort_values(['confidence', 'lift'], ascending =[False, False]) 
rules2.head()
# Out:
#                                            antecedents  \
# 540  (REGENCY CAKESTAND 3 TIER, PINK REGENCY TEACUP...
# 384  (PINK REGENCY TEACUP AND SAUCER, ROSES REGENCY...
# 538  (REGENCY CAKESTAND 3 TIER, GREEN REGENCY TEACU...
# 377  (REGENCY CAKESTAND 3 TIER, PINK REGENCY TEACUP...
# 532  (REGENCY CAKESTAND 3 TIER, PINK REGENCY TEACUP...
#
#                             consequents  antecedent support  \
# 540   (GREEN REGENCY TEACUP AND SAUCER)            0.011331
# 384   (GREEN REGENCY TEACUP AND SAUCER)            0.019288
# 538  (ROSES REGENCY TEACUP AND SAUCER )            0.011583
# 377   (GREEN REGENCY TEACUP AND SAUCER)            0.013345
# 532  (ROSES REGENCY TEACUP AND SAUCER )            0.013345
#
#      consequent support   support  confidence       lift  leverage  conviction
# 540            0.030820  0.010173    0.897778  29.129368  0.009824    9.481105
# 384            0.030820  0.017173    0.890339  28.888023  0.016578    8.837995
# 538            0.034144  0.010173    0.878261  25.722162  0.009777    7.933816
# 377            0.030820  0.011583    0.867925  28.160747  0.011172    7.338074
# 532            0.034144  0.011331    0.849057  24.866839  0.010875    6.398795

# %%
#Germany
# Building the model 
frq_items = apriori(basket_ger,min_support = 0.01, use_colnames = True) 
rules3 = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules3 = rules3.sort_values(['confidence', 'lift'], ascending =[False, False]) 
rules3.head()
# Out:
#                                             antecedents  \
# 7124  (BLUE VINTAGE SPOT BEAKER, GREEN VINTAGE SPOT ...
# 7574  (ROUND SNACK BOXES SET OF4 WOODLAND , SCANDINA...
# 7577  (ROUND SNACK BOXES SET OF 4 FRUITS , SCANDINAV...
# 682                  (STAR WREATH DECORATION WITH BELL)
# 7029  (RED SPOT CERAMIC DRAWER KNOB, WHITE SPOT BLUE...
#
#                                             consequents  antecedent support  \
# 7124  (RED VINTAGE SPOT BEAKER, PINK VINTAGE SPOT BE...            0.011609
# 7574  (CHOCOLATE BOX RIBBONS , ROUND SNACK BOXES SET...            0.011609
# 7577  (ROUND SNACK BOXES SET OF4 WOODLAND , CHOCOLAT...            0.011609
# 682                 (HEART WREATH DECORATION WITH BELL)            0.011609
# 7029  (BLUE SPOT CERAMIC DRAWER KNOB, WHITE SPOT RED...            0.013267
#
#       consequent support   support  confidence    lift  leverage  conviction
# 7124            0.013267  0.011609         1.0  75.375  0.011455         inf
# 7574            0.013267  0.011609         1.0  75.375  0.011455         inf
# 7577            0.013267  0.011609         1.0  75.375  0.011455         inf
# 682             0.014925  0.011609         1.0  67.000  0.011435         inf
# 7029            0.016584  0.013267         1.0  60.300  0.013047         inf

# %%
#France
# Other Countries
frq_items = apriori(basket_other, min_support = 0.01, use_colnames = True) 
rules4 = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules4 = rules4.sort_values(['confidence', 'lift'], ascending =[False, False]) 
rules4.head()
# Out:
#                                              antecedents  \
# 2829   (PACK OF 6 SKULL PAPER PLATES, PACK OF 20 SKUL...
# 4072   (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS ...
# 1982   (DOLLY GIRL CHILDRENS CUP, SPACEBOY CHILDRENS ...
# 4066   (DOLLY GIRL CHILDRENS CUP, SPACEBOY CHILDRENS ...
# 13869  (REGENCY CAKESTAND 3 TIER, REGENCY TEAPOT ROSE...
#
#                                              consequents  antecedent support  \
# 2829                        (PACK OF 6 SKULL PAPER CUPS)            0.011792
# 4072   (DOLLY GIRL CHILDRENS CUP, SPACEBOY CHILDRENS ...            0.013365
# 1982                         (DOLLY GIRL CHILDRENS BOWL)            0.015723
# 4066                         (DOLLY GIRL CHILDRENS BOWL)            0.013365
# 13869  (REGENCY SUGAR BOWL GREEN, REGENCY TEA PLATE G...            0.012579
#
#        consequent support   support  confidence       lift  leverage  \
# 2829             0.014937  0.011792         1.0  66.947368  0.011616
# 4072             0.015723  0.013365         1.0  63.600000  0.013155
# 1982             0.018082  0.015723         1.0  55.304348  0.015439
# 4066             0.018082  0.013365         1.0  55.304348  0.013123
# 13869            0.018082  0.012579         1.0  55.304348  0.012351
#
#        conviction
# 2829          inf
# 4072          inf
# 1982          inf
# 4066          inf
# 13869         inf

# %%
#Combining all the rules
rules=pd.concat([rules1,rules2,rules3,rules4])
rules.reset_index(inplace=True)
rules.drop('index',axis=1,inplace=True)
rules.head()
# Out:
#                                          antecedents  \
# 0                     (SMALL MARSHMALLOWS PINK BOWL)
# 1               (SMALL DOLLY MIX DESIGN ORANGE BOWL)
# 2  (ALARM CLOCK BAKELIKE PINK, PLASTERS IN TIN CI...
# 3  (PLASTERS IN TIN SPACEBOY, ALARM CLOCK BAKELIK...
# 4  (ALARM CLOCK BAKELIKE RED , CHILDRENS CUTLERY ...
#
#                                          consequents  antecedent support  \
# 0               (SMALL DOLLY MIX DESIGN ORANGE BOWL)            0.010917
# 1                     (SMALL MARSHMALLOWS PINK BOWL)            0.010917
# 2  (PLASTERS IN TIN SPACEBOY, ALARM CLOCK BAKELIK...            0.010917
# 3  (ALARM CLOCK BAKELIKE PINK, PLASTERS IN TIN CI...            0.010917
# 4      (ALARM CLOCK BAKELIKE PINK, CARD DOLLY GIRL )            0.010917
#
#    consequent support   support  confidence  lift  leverage  conviction
# 0            0.010917  0.010917         1.0  91.6  0.010798         inf
# 1            0.010917  0.010917         1.0  91.6  0.010798         inf
# 2            0.010917  0.010917         1.0  91.6  0.010798         inf
# 3            0.010917  0.010917         1.0  91.6  0.010798         inf
# 4            0.010917  0.010917         1.0  91.6  0.010798         inf

# %%
#Removing Duplicates Value
rules=rules[~(rules.duplicated(['antecedents']))]

# %%
#Keeping necessy columns
rules_final=rules[['antecedents','consequents']]
rules_final.head()
# Out:
#                                          antecedents  \
# 0                     (SMALL MARSHMALLOWS PINK BOWL)
# 1               (SMALL DOLLY MIX DESIGN ORANGE BOWL)
# 2  (ALARM CLOCK BAKELIKE PINK, PLASTERS IN TIN CI...
# 3  (PLASTERS IN TIN SPACEBOY, ALARM CLOCK BAKELIK...
# 4  (ALARM CLOCK BAKELIKE RED , CHILDRENS CUTLERY ...
#
#                                          consequents
# 0               (SMALL DOLLY MIX DESIGN ORANGE BOWL)
# 1                     (SMALL MARSHMALLOWS PINK BOWL)
# 2  (PLASTERS IN TIN SPACEBOY, ALARM CLOCK BAKELIK...
# 3  (ALARM CLOCK BAKELIKE PINK, PLASTERS IN TIN CI...
# 4      (ALARM CLOCK BAKELIKE PINK, CARD DOLLY GIRL )

# %%
rules_final.reset_index(inplace=True)
rules_final.drop('index',axis=1,inplace=True)
# Out:
# C:\Users\asus\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
for i in range(len(rules_final)):
    x=list(rules_final['consequents'][i])
    y=list(rules_final['antecedents'][i])
    rules_final['antecedents'][i]=y
    rules_final['consequents'][i]=x
# Out:
# C:\Users\asus\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3326: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
for i in range(len(rules_final)):

    x=rules_final['antecedents'][i]
    x=x[0]
    rules_final['antecedents'][i]=x
    y=rules_final['consequents'][i]
    y=y[:2]
    rules_final['consequents'][i]=y

# %%
#Cleaning the data to produce final results
rules_final.columns=['Item','Other Item Bought with it']
rules_final['Length']=rules_final['Item']
rules_final['Length']=rules_final['Other Item Bought with it'].apply(lambda x:len(x))
rules_final=rules_final[rules_final['Length']>1]
rules_final.drop('Length',axis=1,inplace=True)

from sklearn.utils import shuffle
rules_final=shuffle(rules_final)

rules_final.reset_index(inplace=True)
rules_final.drop('index',axis=1,inplace=True)
rules_final.head()
# Out:
# C:\Users\asus\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\asus\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                   Item  \
# 0        SET/6 RED SPOTTY PAPER PLATES
# 1           ALARM CLOCK BAKELIKE GREEN
# 2  ROUND SNACK BOXES SET OF4 WOODLAND
# 3        SET/6 RED SPOTTY PAPER PLATES
# 4       PLASTERS IN TIN CIRCUS PARADE
#
#                            Other Item Bought with it
# 0  [ROUND SNACK BOXES SET OF4 WOODLAND , PLASTERS...
# 1  [SET/6 RED SPOTTY PAPER PLATES, ALARM CLOCK BA...
# 2  [ALARM CLOCK BAKELIKE RED , ALARM CLOCK BAKELI...
# 3  [SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...
# 4  [ALARM CLOCK BAKELIKE PINK, PLASTERS IN TIN SP...

# %%
rules_final.to_csv('Assignment-2.csv')
